# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import PIL

#from utils import *
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

print (device)
# Out:
# cuda:0

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ### Reading data

# %%
def shuffle_data(X, y):
    r = np.random.permutation(len(y))
    return X[r], y[r]

# %%
data = np.genfromtxt('./train.csv', delimiter=',')
data = np.delete(data, (0), axis=0)
data_np_y = data[:,0]
data = np.delete(data, (0), axis=1)
data_np_x = data / 255

data_np_x, data_np_y = shuffle_data(data_np_x, data_np_y)

# %%
fig = plt.figure(figsize=(20,10), dpi=80)
shape = (1,10)
for j in range(10):
    ax = fig.add_subplot(shape[0], shape[1], j+1)
    image = data_np_x[j].reshape(28,28)
    ax.matshow(image, cmap=matplotlib.cm.binary)
    plt.xticks(np.array([]))
    plt.yticks(np.array([]))
plt.show()

print (data_np_y[:10])
# Out:
# [7. 3. 6. 6. 9. 7. 6. 6. 2. 3.]

# %% [markdown]
# ### Data augmentation

# %%
noise_factor = 0.1
# Add random noise to the input images
data_noisy_x1 = data_np_x + noise_factor * np.random.randn(*data_np_x.shape)
# Clip the images to be between 0 and 1
data_noisy_x1 = np.clip(data_noisy_x1, 0., 1.)

data_noisy_y1 = data_np_y

# %%
fig = plt.figure(figsize=(20,10), dpi=80)
shape = (1,10)
for j in range(10):
    ax = fig.add_subplot(shape[0], shape[1], j+1)
    image = data_noisy_x1[j].reshape(28,28)
    ax.matshow(image, cmap=matplotlib.cm.binary)
    plt.xticks(np.array([]))
    plt.yticks(np.array([]))
plt.show()

print (data_noisy_y1[:10])
# Out:
# [7. 3. 6. 6. 9. 7. 6. 6. 2. 3.]

# %%
noise_factor = 0.2
# Add random noise to the input images
data_noisy_x2 = data_np_x + noise_factor * np.random.randn(*data_np_x.shape)
# Clip the images to be between 0 and 1
data_noisy_x2 = np.clip(data_noisy_x2, 0., 1.)

data_noisy_y2 = data_np_y

# %%
fig = plt.figure(figsize=(20,10), dpi=80)
shape = (1,10)
for j in range(10):
    ax = fig.add_subplot(shape[0], shape[1], j+1)
    image = data_noisy_x2[j].reshape(28,28)
    ax.matshow(image, cmap=matplotlib.cm.binary)
    plt.xticks(np.array([]))
    plt.yticks(np.array([]))
plt.show()

print (data_noisy_y2[:10])
# Out:
# [7. 3. 6. 6. 9. 7. 6. 6. 2. 3.]

# %%
noise_factor = 0.3
# Add random noise to the input images
data_noisy_x3 = data_np_x + noise_factor * np.random.randn(*data_np_x.shape)
# Clip the images to be between 0 and 1
data_noisy_x3 = np.clip(data_noisy_x3, 0., 1.)

data_noisy_y3 = data_np_y

# %%
fig = plt.figure(figsize=(20,10), dpi=80)
shape = (1,10)
for j in range(10):
    ax = fig.add_subplot(shape[0], shape[1], j+1)
    image = data_noisy_x3[j].reshape(28,28)
    ax.matshow(image, cmap=matplotlib.cm.binary)
    plt.xticks(np.array([]))
    plt.yticks(np.array([]))
plt.show()

print (data_noisy_y1[:10])
# Out:
# [7. 3. 6. 6. 9. 7. 6. 6. 2. 3.]

# %% [markdown]
# ### Making final dataset

# %%
data_x = np.vstack((data_np_x, data_noisy_x1, data_noisy_x2, data_noisy_x3))
data_y = np.hstack((data_np_y, data_noisy_y1, data_noisy_y2, data_noisy_y3))

data_x, data_y = shuffle_data(data_x, data_y)
#print (data_np_x.shape, data_noisy_x.shape)
print (data_x.shape, data_y.shape)
# Out:
# (168000, 784) (168000,)

# %%
fig = plt.figure(figsize=(20,10), dpi=80)
shape = (1,10)
for j in range(10):
    ax = fig.add_subplot(shape[0], shape[1], j+1)
    image = data_x[j].reshape(28,28)
    ax.matshow(image, cmap=matplotlib.cm.binary)
    plt.xticks(np.array([]))
    plt.yticks(np.array([]))
plt.show()

print (data_y[:10])
# Out:
# [1. 4. 5. 0. 1. 0. 2. 1. 9. 6.]

# %%
pos = int(data_x.shape[0] * 0.9)

train_np_y = data_y[:pos]
train_np_x = data_x[:pos]
test_np_y = data_y[pos:]
test_np_x = data_x[pos:]

# %%
print (data_x.shape, data_y.shape)
print (train_np_x.shape, train_np_y.shape)
print (test_np_x.shape, test_np_y.shape)
# Out:
# (168000, 784) (168000,)
# (151200, 784) (151200,)
# (16800, 784) (16800,)

# %%
def normalize(x):
    x = (x - 0.1307) / 0.3081    
    return x

# %%
train_x = torch.Tensor(np.expand_dims(normalize(train_np_x), axis=1)).to(device)
train_y = torch.LongTensor(train_np_y).to(device)

test_x = torch.Tensor(np.expand_dims(normalize(test_np_x), axis=1)).to(device)
test_y = torch.LongTensor(test_np_y).to(device)

# %% [markdown]
# ## Neural network

# %%
def loader(x, y, batch_size=64):
    for i in range(0, x.size(0) - 1, batch_size):
        data = x[i:i+batch_size]        
        if data.shape[0] == batch_size:
            data = data.reshape(batch_size, 1, 28, 28)
            targets = y[i:i+batch_size]

            yield data, targets

# %%
class ConvLayer(nn.Module):
    def __init__(self, size, padding=1, pool_layer=nn.MaxPool2d(2, stride=2),
                 bn=False, dropout=False, activation_fn=nn.ReLU(), stride=1):
        super(ConvLayer, self).__init__()
        layers = []        
        layers.append(nn.Conv2d(size[0], size[1], size[2], padding=padding, stride=stride))
        if pool_layer is not None:
            layers.append(pool_layer)
        if bn:
            layers.append(nn.BatchNorm2d(size[1]))
        if dropout:
            layers.append(nn.Dropout2d())
        layers.append(activation_fn)
        
        self.model = nn.Sequential(*layers).to(device)
    
    def forward(self, x):
        return self.model(x)

# %%
class FullyConnected(nn.Module):
    def __init__(self, sizes, dropout=False, activation_fn=nn.Tanh):
        super(FullyConnected, self).__init__()
        layers = []
        
        for i in range(len(sizes) - 2):
            layers.append(nn.Linear(sizes[i], sizes[i+1]))
            if dropout:
                layers.append(nn.Dropout())
            layers.append(activation_fn())
        else: # нам не нужен дропаут и фнкция активации в последнем слое
            layers.append(nn.Linear(sizes[-2], sizes[-1]))            
        
        self.model = nn.Sequential(*layers).to(device)
        
    def forward(self, x):
        return self.model(x)

# %%
class Net(nn.Module):
    def __init__(self, batchnorm=False, dropout=False, lr=5e-5, l2=.0):
        super(Net, self).__init__()
        
        
        #self._conv1 = ConvLayer([1, 16, 3], bn=batchnorm)   
        #self._conv2 = ConvLayer([16, 32, 3], bn=batchnorm) 
        #self._conv3 = ConvLayer([32, 64, 3], bn=batchnorm, activation_fn=nn.Sigmoid())
    
        self._conv1 = ConvLayer([1, 64, 3], padding=0, bn=batchnorm, stride=2, pool_layer=None)
        self._conv2 = ConvLayer([64, 128, 3], padding=0, bn=batchnorm, stride=2, 
                                pool_layer=None)
        self._conv3 = ConvLayer([128, 128, 3], padding=0, bn=batchnorm, stride=2, 
                                pool_layer=None, activation_fn=nn.Sigmoid())
        
        self.fc = FullyConnected([128*2*2, 256, 10], dropout=dropout)
        
        self.lr = lr
        self.lr_base = lr
        self.l2 = l2
        self._loss = None
        self.optim = optim.Adam(self.parameters(), lr=self.lr, weight_decay=self.l2)
    
    def conv(self, x):        
        x = self._conv1(x)
        x = self._conv2(x)
        x = self._conv3(x)    
        return x
        
    def forward(self, x):        
        x = self.conv(x)
        x = x.view(-1, 128*2*2) # 64*7*7
        x = self.fc(x)        
        return x
    
    def loss(self, output, target, **kwargs):         
        self._loss = F.cross_entropy(output, target, **kwargs)
        self._correct = output.data.max(1, keepdim=True)[1]
        self._correct = self._correct.eq(target.data.view_as(self._correct)).to(torch.float).cpu().mean()
        return self._loss

# %%
def train(epoch, models, log=None):    
    for model in models.values():
        model.lr = model.lr_base * (50 / (epoch + 50))        
        model.optim = optim.Adam(model.parameters(), lr=model.lr, weight_decay=model.l2)
    print ("LR: {}".format(models['plain'].lr))    
    train_size = len(train_x)
       
    
    for batch_idx, (data, target) in enumerate(loader(train_x, train_y, batch_size=32)):        
        for model in models.values():                             
            model.optim.zero_grad()
            output = model(data)
            loss = model.loss(output, target)
            loss.backward()
            model.optim.step()
            
        if batch_idx % 1000 == 0:
            line = 'Train Epoch: {} [{}/{} ({:.0f}%)]\tLosses '.format(
                epoch, batch_idx * len(data), train_size, 100. * batch_idx / train_size)
            losses = ' '.join(['{}: {:.6f}'.format(k, m._loss.item()) for k, m in models.items()])
            print(line + losses)
            
    else:
        batch_idx += 1
        line = 'Train Epoch: {} [{}/{} ({:.0f}%)]\tLosses '.format(
            epoch, batch_idx * len(data), train_size, 100. * batch_idx / train_size)
        losses = ' '.join(['{}: {:.6f}'.format(k, m._loss.item()) for k, m in models.items()])
        if log is not None:
            for k in models:
                log[k].append((models[k]._loss, models[k]._correct))
        print(line + losses)

# %%
def test(models, log=None):
    test_size = len(test_x)
    avg_lambda = lambda l: 'Loss: {:.4f}'.format(l)
    acc_lambda = lambda c, p: 'Accuracy: {}/{} ({:.0f}%)'.format(c, test_size, p)
    line = lambda i, l, c, p: '{}: '.format(i) + avg_lambda(l) + '\t' + acc_lambda(c, p)

    test_loss = {k: 0. for k in models}
    correct = {k: 0. for k in models}
    with torch.no_grad():
        for data, target in loader(test_x, test_y, batch_size=32):
            output = {k: m(data) for k, m in models.items()}           
            for k, m in models.items():     
                #print (output[k].shape, target.shape)
                test_loss[k] += m.loss(output[k], target, size_average=False).item() # sum up batch loss
                pred = output[k].data.max(1, keepdim=True)[1] # get the index of the max log-probability
                correct[k] += pred.eq(target.data.view_as(pred)).cpu().sum().item()
    
    for k in models:
        test_loss[k] /= test_size
    correct_pct = {k: c / test_size for k, c in correct.items()}
    lines = '\n'.join([line(k, test_loss[k], correct[k], 100*correct_pct[k]) for k in models]) + '\n'
    report = 'Test set:\n' + lines
    if log is not None:
        for k in models:
            log[k].append((test_loss[k], correct_pct[k]))
    print(report)

# %%
def plot_graphs(log, tpe='loss'):
    keys = log.keys()
    logs = {k:[z for z in zip(*log[k])] for k in keys}
    epochs = {k:range(len(log[k])) for k in keys}
 
    
    if tpe == 'loss':
        handlers, = zip(*[plt.plot(epochs[k], logs[k][0], label=k) for k in keys])
        plt.title('errors')
        plt.xlabel('epoch')
        plt.ylabel('error')
        plt.legend(handles=handlers)
        plt.show()
    elif tpe == 'accuracy':
        handlers, = zip(*[plt.plot(epochs[k], logs[k][1], label=k) for k in log.keys()])
        plt.title('accuracy')
        plt.xlabel('epoch')
        plt.ylabel('accuracy')
        plt.legend(handles=handlers)
        plt.show()

# %%
models = {'plain': Net(), 'drop': Net(False, True)}
train_log = {k: [] for k in models}
test_log = {k: [] for k in models}

# %%
print (models['plain'])
# Out:
# Net(
#   (_conv1): ConvLayer(
#     (model): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(2, 2))
#       (1): ReLU()
#     )
#   )
#   (_conv2): ConvLayer(
#     (model): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2))
#       (1): ReLU()
#     )
#   )
#   (_conv3): ConvLayer(
#     (model): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2))
#       (1): Sigmoid()
#     )
#   )
#   (fc): FullyConnected(
#     (model): Sequential(
#       (0): Linear(in_features=512, out_features=256, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=256, out_features=10, bias=True)
#     )
#   )
# )

# %%
for epoch in range(1, 201):
    for model in models.values():
        model.train()
    train_x, train_y = shuffle_data(train_x, train_y)    
    train(epoch, models, train_log)
    for model in models.values():
        model.eval()
    test(models, test_log)
# Out:
# LR: 4.901960784313725e-05
# Train Epoch: 1 [0/151200 (0%)]	Losses plain: 0.193555 drop: 0.235186
# Train Epoch: 1 [32000/151200 (1%)]	Losses plain: 0.029758 drop: 0.044689
# Train Epoch: 1 [64000/151200 (1%)]	Losses plain: 0.160749 drop: 0.190897
# Train Epoch: 1 [96000/151200 (2%)]	Losses plain: 0.180249 drop: 0.214713
# Train Epoch: 1 [128000/151200 (3%)]	Losses plain: 0.042281 drop: 0.049333
# Train Epoch: 1 [151200/151200 (3%)]	Losses plain: 0.101113 drop: 0.086351
# /home/aleksey/.conda/envs/kaggle/lib/python3.6/site-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Test set:
# plain: Loss: 0.0939	Accuracy: 16353.0/16800 (97%)
# drop: Loss: 0.0913	Accuracy: 16325.0/16800 (97%)
#
# LR: 4.8076923076923084e-05
# Train Epoch: 2 [0/151200 (0%)]	Losses plain: 0.247925 drop: 0.295649
# Train Epoch: 2 [32000/151200 (1%)]	Losses plain: 0.116234 drop: 0.143529
# Train Epoch: 2 [64000/151200 (1%)]	Losses plain: 0.031610 drop: 0.093237
# Train Epoch: 2 [96000/151200 (2%)]	Losses plain: 0.190246 drop: 0.147939
# Train Epoch: 2 [128000/151200 (3%)]	Losses plain: 0.028979 drop: 0.040138
# Train Epoch: 2 [151200/151200 (3%)]	Losses plain: 0.007217 drop: 0.020033
# Test set:
# Train Epoch: 24 [96000/151200 (2%)]	Losses plain: 0.000207 drop: 0.003887
# Train Epoch: 24 [128000/151200 (3%)]	Losses plain: 0.000008 drop: 0.000044
# Train Epoch: 24 [151200/151200 (3%)]	Losses plain: 0.000024 drop: 0.001641
# Test set:
# plain: Loss: 0.0051	Accuracy: 16776.0/16800 (100%)
# drop: Loss: 0.0031	Accuracy: 16784.0/16800 (100%)
#
# LR: 3.3333333333333335e-05
# Train Epoch: 25 [0/151200 (0%)]	Losses plain: 0.000146 drop: 0.000023
# Train Epoch: 25 [32000/151200 (1%)]	Losses plain: 0.000002 drop: 0.000131
# Train Epoch: 25 [64000/151200 (1%)]	Losses plain: 0.000022 drop: 0.000009
# Train Epoch: 25 [96000/151200 (2%)]	Losses plain: 0.003164 drop: 0.002815
# Train Epoch: 25 [128000/151200 (3%)]	Losses plain: 0.000021 drop: 0.000014
# Train Epoch: 25 [151200/151200 (3%)]	Losses plain: 0.000001 drop: 0.000019
# Test set:
# plain: Loss: 0.0058	Accuracy: 16772.0/16800 (100%)
# drop: Loss: 0.0051	Accuracy: 16772.0/16800 (100%)
#
# LR: 3.289473684210527e-05
# Train Epoch: 26 [0/151200 (0%)]	Losses plain: 0.000005 drop: 0.000023
# Train Epoch: 26 [32000/151200 (1%)]	Losses plain: 0.000000 drop: 0.000008
# Train Epoch: 26 [64000/151200 (1%)]	Losses plain: 0.000120 drop: 0.000999
# Train Epoch: 26 [96000/151200 (2%)]	Losses plain: 0.000080 drop: 0.002140
# Train Epoch: 26 [128000/151200 (3%)]	Losses plain: 0.000154 drop: 0.000180
# Train Epoch: 26 [151200/151200 (3%)]	Losses plain: 0.000209 drop: 0.001775
# Test set:
# plain: Loss: 0.0055	Accuracy: 16779.0/16800 (100%)
# drop: Loss: 0.0039	Accuracy: 16781.0/16800 (100%)
#
# LR: 3.246753246753247e-05
# Train Epoch: 27 [0/151200 (0%)]	Losses plain: 0.000014 drop: 0.000021
# Train Epoch: 27 [32000/151200 (1%)]	Losses plain: 0.000739 drop: 0.000030
# Train Epoch: 27 [64000/151200 (1%)]	Losses plain: 0.000023 drop: 0.000199
# Train Epoch: 27 [96000/151200 (2%)]	Losses plain: 0.000003 drop: 0.000002
# Train Epoch: 27 [128000/151200 (3%)]	Losses plain: 0.000001 drop: 0.000085
# Train Epoch: 27 [151200/151200 (3%)]	Losses plain: 0.000021 drop: 0.000106
# Test set:
# plain: Loss: 0.0051	Accuracy: 16778.0/16800 (100%)
# drop: Loss: 0.0047	Accuracy: 16772.0/16800 (100%)
#
# LR: 3.205128205128206e-05
# Train Epoch: 28 [0/151200 (0%)]	Losses plain: 0.000030 drop: 0.000169
# Train Epoch: 28 [32000/151200 (1%)]	Losses plain: 0.000019 drop: 0.000061
# Train Epoch: 28 [64000/151200 (1%)]	Losses plain: 0.000037 drop: 0.000021
# Train Epoch: 28 [96000/151200 (2%)]	Losses plain: 0.000016 drop: 0.000022
# Train Epoch: 28 [128000/151200 (3%)]	Losses plain: 0.000003 drop: 0.000033
# Train Epoch: 28 [151200/151200 (3%)]	Losses plain: 0.000010 drop: 0.000053
# Test set:
# plain: Loss: 0.0052	Accuracy: 16777.0/16800 (100%)
# drop: Loss: 0.0033	Accuracy: 16781.0/16800 (100%)
#
# LR: 3.1645569620253167e-05
# Train Epoch: 29 [0/151200 (0%)]	Losses plain: 0.000001 drop: 0.000002
# Train Epoch: 29 [32000/151200 (1%)]	Losses plain: 0.000047 drop: 0.000109
# Train Epoch: 29 [64000/151200 (1%)]	Losses plain: 0.000006 drop: 0.000015
# Train Epoch: 29 [96000/151200 (2%)]	Losses plain: 0.000091 drop: 0.001366
# Train Epoch: 29 [128000/151200 (3%)]	Losses plain: 0.000003 drop: 0.001736
# Train Epoch: 29 [151200/151200 (3%)]	Losses plain: 0.000060 drop: 0.000045
# Test set:
# plain: Loss: 0.0053	Accuracy: 16772.0/16800 (100%)
# drop: Loss: 0.0033	Accuracy: 16781.0/16800 (100%)
#
# LR: 3.125e-05
# Train Epoch: 30 [0/151200 (0%)]	Losses plain: 0.000003 drop: 0.000242
# Train Epoch: 30 [32000/151200 (1%)]	Losses plain: 0.000011 drop: 0.001815
# Train Epoch: 30 [64000/151200 (1%)]	Losses plain: 0.000002 drop: 0.000024
# Train Epoch: 30 [96000/151200 (2%)]	Losses plain: 0.000164 drop: 0.000454
# Train Epoch: 30 [128000/151200 (3%)]	Losses plain: 0.000013 drop: 0.000018
# Train Epoch: 30 [151200/151200 (3%)]	Losses plain: 0.000020 drop: 0.000006
# Test set:
# plain: Loss: 0.0064	Accuracy: 16772.0/16800 (100%)
# drop: Loss: 0.0043	Accuracy: 16782.0/16800 (100%)
#
# LR: 3.08641975308642e-05
# Train Epoch: 31 [0/151200 (0%)]	Losses plain: 0.000023 drop: 0.000087
# Train Epoch: 31 [32000/151200 (1%)]	Losses plain: 0.000003 drop: 0.000149
# Train Epoch: 31 [64000/151200 (1%)]	Losses plain: 0.000024 drop: 0.000113
# Train Epoch: 31 [96000/151200 (2%)]	Losses plain: 0.000000 drop: 0.000004
# Train Epoch: 31 [128000/151200 (3%)]	Losses plain: 0.000006 drop: 0.000111
# Train Epoch: 31 [151200/151200 (3%)]	Losses plain: 0.000001 drop: 0.000018
# Test set:
# plain: Loss: 0.0056	Accuracy: 16770.0/16800 (100%)
# drop: Loss: 0.0059	Accuracy: 16768.0/16800 (100%)
#
# LR: 3.048780487804878e-05
# Train Epoch: 32 [0/151200 (0%)]	Losses plain: 0.000138 drop: 0.000044
# Train Epoch: 32 [32000/151200 (1%)]	Losses plain: 0.000009 drop: 0.000051
# Train Epoch: 32 [64000/151200 (1%)]	Losses plain: 0.000005 drop: 0.000500
# Train Epoch: 32 [96000/151200 (2%)]	Losses plain: 0.000235 drop: 0.000005
# Train Epoch: 32 [128000/151200 (3%)]	Losses plain: 0.000106 drop: 0.000128
# Train Epoch: 32 [151200/151200 (3%)]	Losses plain: 0.000000 drop: 0.000008
# Test set:
# plain: Loss: 0.0053	Accuracy: 16776.0/16800 (100%)
# drop: Loss: 0.0044	Accuracy: 16776.0/16800 (100%)
#
# LR: 3.012048192771085e-05
# Train Epoch: 33 [0/151200 (0%)]	Losses plain: 0.000003 drop: 0.000102
# Train Epoch: 37 [96000/151200 (2%)]	Losses plain: 0.000000 drop: 0.000004
# Train Epoch: 37 [128000/151200 (3%)]	Losses plain: 0.000028 drop: 0.000009
# Train Epoch: 37 [151200/151200 (3%)]	Losses plain: 0.000000 drop: 0.000002
# Test set:
# plain: Loss: 0.0054	Accuracy: 16776.0/16800 (100%)
# drop: Loss: 0.0047	Accuracy: 16777.0/16800 (100%)
#
# LR: 2.8409090909090912e-05
# Train Epoch: 38 [0/151200 (0%)]	Losses plain: 0.000000 drop: 0.000598
# Train Epoch: 38 [32000/151200 (1%)]	Losses plain: 0.000003 drop: 0.000067
# Train Epoch: 38 [64000/151200 (1%)]	Losses plain: 0.000001 drop: 0.000010
# Train Epoch: 38 [96000/151200 (2%)]	Losses plain: 0.000001 drop: 0.000003
# Train Epoch: 38 [128000/151200 (3%)]	Losses plain: 0.000000 drop: 0.000009
# Train Epoch: 38 [151200/151200 (3%)]	Losses plain: 0.000000 drop: 0.000015
# Test set:
# plain: Loss: 0.0061	Accuracy: 16775.0/16800 (100%)
# drop: Loss: 0.0056	Accuracy: 16773.0/16800 (100%)
#
# LR: 2.8089887640449443e-05
# Train Epoch: 39 [0/151200 (0%)]	Losses plain: 0.000000 drop: 0.000003
# Train Epoch: 39 [32000/151200 (1%)]	Losses plain: 0.000000 drop: 0.000467
# Train Epoch: 39 [64000/151200 (1%)]	Losses plain: 0.000015 drop: 0.000336
# Train Epoch: 39 [96000/151200 (2%)]	Losses plain: 0.000000 drop: 0.000212
# Train Epoch: 39 [128000/151200 (3%)]	Losses plain: 0.000000 drop: 0.000004
# Train Epoch: 39 [151200/151200 (3%)]	Losses plain: 0.000000 drop: 0.000003
# Test set:
# plain: Loss: 0.0053	Accuracy: 16780.0/16800 (100%)
# drop: Loss: 0.0035	Accuracy: 16785.0/16800 (100%)
#
# LR: 2.777777777777778e-05
# Train Epoch: 40 [0/151200 (0%)]	Losses plain: 0.000001 drop: 0.000002
# Train Epoch: 40 [32000/151200 (1%)]	Losses plain: 0.000000 drop: 0.000002
# Train Epoch: 40 [64000/151200 (1%)]	Losses plain: 0.000001 drop: 0.000003
# Train Epoch: 40 [96000/151200 (2%)]	Losses plain: 0.000002 drop: 0.000055
# Train Epoch: 40 [128000/151200 (3%)]	Losses plain: 0.000000 drop: 0.000005
# Train Epoch: 40 [151200/151200 (3%)]	Losses plain: 0.000000 drop: 0.000150
# Test set:
# plain: Loss: 0.0063	Accuracy: 16771.0/16800 (100%)
# drop: Loss: 0.0038	Accuracy: 16782.0/16800 (100%)
#
# LR: 2.7472527472527476e-05
# Train Epoch: 41 [0/151200 (0%)]	Losses plain: 0.000008 drop: 0.000006
# Train Epoch: 41 [32000/151200 (1%)]	Losses plain: 0.000000 drop: 0.000002
# Train Epoch: 41 [64000/151200 (1%)]	Losses plain: 0.000000 drop: 0.000000
# Train Epoch: 41 [96000/151200 (2%)]	Losses plain: 0.000032 drop: 0.000100
# Train Epoch: 41 [128000/151200 (3%)]	Losses plain: 0.000001 drop: 0.000014
# Train Epoch: 41 [151200/151200 (3%)]	Losses plain: 0.000000 drop: 0.000309
# Test set:
# plain: Loss: 0.0063	Accuracy: 16779.0/16800 (100%)
# drop: Loss: 0.0048	Accuracy: 16779.0/16800 (100%)
#
# LR: 2.7173913043478262e-05
# Train Epoch: 42 [0/151200 (0%)]	Losses plain: 0.000000 drop: 0.000002
# Train Epoch: 42 [32000/151200 (1%)]	Losses plain: 0.000021 drop: 0.000007
# Train Epoch: 42 [64000/151200 (1%)]	Losses plain: 0.000003 drop: 0.000185
# Train Epoch: 42 [96000/151200 (2%)]	Losses plain: 0.000000 drop: 0.000001
# Train Epoch: 42 [128000/151200 (3%)]	Losses plain: 0.000024 drop: 0.000005
# Train Epoch: 42 [151200/151200 (3%)]	Losses plain: 0.000000 drop: 0.000001
# Test set:
# plain: Loss: 0.0090	Accuracy: 16767.0/16800 (100%)
# drop: Loss: 0.0051	Accuracy: 16783.0/16800 (100%)
#
# LR: 2.6881720430107527e-05
# Train Epoch: 43 [0/151200 (0%)]	Losses plain: 0.000000 drop: 0.000003
# Train Epoch: 43 [32000/151200 (1%)]	Losses plain: 0.000000 drop: 0.000000
# Train Epoch: 43 [64000/151200 (1%)]	Losses plain: 0.000001 drop: 0.000005
# Train Epoch: 43 [96000/151200 (2%)]	Losses plain: 0.000001 drop: 0.000005
# Train Epoch: 43 [128000/151200 (3%)]	Losses plain: 0.000000 drop: 0.000000
# Train Epoch: 43 [151200/151200 (3%)]	Losses plain: 0.000000 drop: 0.000000
# Test set:
# plain: Loss: 0.0072	Accuracy: 16776.0/16800 (100%)
# drop: Loss: 0.0036	Accuracy: 16782.0/16800 (100%)
#
# LR: 2.6595744680851064e-05
# Train Epoch: 44 [0/151200 (0%)]	Losses plain: 0.000015 drop: 0.000002
# Train Epoch: 44 [32000/151200 (1%)]	Losses plain: 0.000000 drop: 0.000034
# Train Epoch: 44 [64000/151200 (1%)]	Losses plain: 0.000000 drop: 0.000000
# Train Epoch: 44 [96000/151200 (2%)]	Losses plain: 0.000000 drop: 0.000000
# Train Epoch: 44 [128000/151200 (3%)]	Losses plain: 0.000001 drop: 0.000004
# Train Epoch: 44 [151200/151200 (3%)]	Losses plain: 0.000000 drop: 0.000002
# Test set:
# plain: Loss: 0.0053	Accuracy: 16779.0/16800 (100%)
# drop: Loss: 0.0040	Accuracy: 16777.0/16800 (100%)
#
# LR: 2.6315789473684212e-05
# Train Epoch: 45 [0/151200 (0%)]	Losses plain: 0.000003 drop: 0.000022
# Train Epoch: 45 [32000/151200 (1%)]	Losses plain: 0.000005 drop: 0.000003
# Train Epoch: 45 [64000/151200 (1%)]	Losses plain: 0.000008 drop: 0.000003
# Train Epoch: 45 [96000/151200 (2%)]	Losses plain: 0.000013 drop: 0.000314
# Train Epoch: 45 [128000/151200 (3%)]	Losses plain: 0.000000 drop: 0.000001
# Train Epoch: 45 [151200/151200 (3%)]	Losses plain: 0.000000 drop: 0.000001
# Test set:
# plain: Loss: 0.0056	Accuracy: 16781.0/16800 (100%)
# drop: Loss: 0.0050	Accuracy: 16779.0/16800 (100%)
#
# LR: 2.604166666666667e-05
# Train Epoch: 46 [0/151200 (0%)]	Losses plain: 0.000000 drop: 0.000000
# Train Epoch: 46 [32000/151200 (1%)]	Losses plain: 0.000000 drop: 0.000056
# Train Epoch: 46 [64000/151200 (1%)]	Losses plain: 0.000013 drop: 0.000003
# Train Epoch: 46 [96000/151200 (2%)]	Losses plain: 0.000109 drop: 0.000012
# Train Epoch: 46 [128000/151200 (3%)]	Losses plain: 0.000002 drop: 0.000003
# Train Epoch: 46 [151200/151200 (3%)]	Losses plain: 0.000001 drop: 0.000001
# Test set:
# plain: Loss: 0.0058	Accuracy: 16781.0/16800 (100%)
# drop: Loss: 0.0036	Accuracy: 16783.0/16800 (100%)
#
# LR: 2.5773195876288658e-05
# Train Epoch: 47 [0/151200 (0%)]	Losses plain: 0.000000 drop: 0.000003
# Train Epoch: 47 [32000/151200 (1%)]	Losses plain: 0.000000 drop: 0.000052
# Train Epoch: 47 [64000/151200 (1%)]	Losses plain: 0.000000 drop: 0.000002
# Train Epoch: 47 [96000/151200 (2%)]	Losses plain: 0.000005 drop: 0.000004
# Train Epoch: 47 [128000/151200 (3%)]	Losses plain: 0.000001 drop: 0.000007
# Train Epoch: 47 [151200/151200 (3%)]	Losses plain: 0.000000 drop: 0.000008
# Test set:
# plain: Loss: 0.0059	Accuracy: 16780.0/16800 (100%)
# drop: Loss: 0.0039	Accuracy: 16784.0/16800 (100%)
#
# LR: 2.5510204081632654e-05
# Train Epoch: 48 [0/151200 (0%)]	Losses plain: 0.000000 drop: 0.000001
# Train Epoch: 48 [32000/151200 (1%)]	Losses plain: 0.000000 drop: 0.000021
# Train Epoch: 48 [64000/151200 (1%)]	Losses plain: 0.000001 drop: 0.000001
# Train Epoch: 48 [96000/151200 (2%)]	Losses plain: 0.000000 drop: 0.000001
# Train Epoch: 48 [128000/151200 (3%)]	Losses plain: 0.000000 drop: 0.000000
# Train Epoch: 48 [151200/151200 (3%)]	Losses plain: 0.000003 drop: 0.000001
# Test set:
# plain: Loss: 0.0053	Accuracy: 16785.0/16800 (100%)
# drop: Loss: 0.0033	Accuracy: 16785.0/16800 (100%)
#
# LR: 2.5252525252525256e-05
# Train Epoch: 49 [0/151200 (0%)]	Losses plain: 0.000000 drop: 0.000013
# Train Epoch: 49 [32000/151200 (1%)]	Losses plain: 0.000000 drop: 0.000025
# Train Epoch: 49 [64000/151200 (1%)]	Losses plain: 0.000000 drop: 0.000001
# Train Epoch: 49 [96000/151200 (2%)]	Losses plain: 0.000004 drop: 0.000012
# Train Epoch: 49 [128000/151200 (3%)]	Losses plain: 0.000000 drop: 0.000036
# Train Epoch: 49 [151200/151200 (3%)]	Losses plain: 0.000000 drop: 0.000008
# Test set:
# plain: Loss: 0.0059	Accuracy: 16774.0/16800 (100%)
# drop: Loss: 0.0033	Accuracy: 16785.0/16800 (100%)
#
# LR: 2.5e-05
# Train Epoch: 50 [0/151200 (0%)]	Losses plain: 0.000002 drop: 0.000014
# Train Epoch: 50 [32000/151200 (1%)]	Losses plain: 0.000000 drop: 0.000000
# Train Epoch: 50 [64000/151200 (1%)]	Losses plain: 0.000000 drop: 0.000047
# Train Epoch: 50 [96000/151200 (2%)]	Losses plain: 0.000000 drop: 0.000000
# Train Epoch: 50 [128000/151200 (3%)]	Losses plain: 0.000000 drop: 0.000010
# Train Epoch: 50 [151200/151200 (3%)]	Losses plain: 0.000000 drop: 0.000004
# Test set:
# plain: Loss: 0.0051	Accuracy: 16780.0/16800 (100%)
# drop: Loss: 0.0032	Accuracy: 16788.0/16800 (100%)
#
# LR: 2.4752475247524754e-05
# Train Epoch: 51 [0/151200 (0%)]	Losses plain: 0.000000 drop: 0.000000
# Train Epoch: 51 [32000/151200 (1%)]	Losses plain: 0.000000 drop: 0.000035
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-8ec102207223> in <module>
#       3         model.train()
#       4     train_x, train_y = shuffle_data(train_x, train_y)
# ----> 5     train(epoch, models, train_log)
#       6     for model in models.values():
#       7         model.eval()
#
# <ipython-input-22-8007c30c78b7> in train(epoch, models, log)
#      11             model.optim.zero_grad()
#      12             output = model(data)
# ---> 13             loss = model.loss(output, target)
#      14             loss.backward()
#      15             model.optim.step()
#
# <ipython-input-21-93060abd95be> in loss(self, output, target, **kwargs)
#      37         self._loss = F.cross_entropy(output, target, **kwargs)
#      38         self._correct = output.data.max(1, keepdim=True)[1]
# ---> 39         self._correct = self._correct.eq(target.data.view_as(self._correct)).to(torch.float).cpu().mean()
#      40         return self._loss
#
# KeyboardInterrupt:

# %%
plot_graphs(test_log, 'loss')

# %%
plot_graphs(test_log, 'accuracy')

# %% [markdown]
# ## Submission

# %%
data = np.genfromtxt('./test.csv', delimiter=',')
data = np.delete(data, (0), axis=0)
data_np_x = data / 255

testing_x = torch.Tensor(np.expand_dims(normalize(data_np_x), axis=1)).to(device)
testing_y = torch.LongTensor(np.zeros((testing_x.shape[0], 1))).to(device)

# %%
print (testing_x.shape)
# Out:
# torch.Size([28000, 1, 784])

# %%
answers = np.empty((0, 10))
model = models['drop']
print (model)

for batch_idx, (data, target) in enumerate(loader(testing_x, testing_y, batch_size=32)):
    output = model(data)  
    output_np = output.cpu().detach().numpy()        
    answers = np.vstack((answers, output_np))
        
print (answers.shape)
# Out:
# Net(
#   (_conv1): ConvLayer(
#     (model): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(2, 2))
#       (1): ReLU()
#     )
#   )
#   (_conv2): ConvLayer(
#     (model): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2))
#       (1): ReLU()
#     )
#   )
#   (_conv3): ConvLayer(
#     (model): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2))
#       (1): Sigmoid()
#     )
#   )
#   (fc): FullyConnected(
#     (model): Sequential(
#       (0): Linear(in_features=512, out_features=256, bias=True)
#       (1): Dropout(p=0.5, inplace=False)
#       (2): Tanh()
#       (3): Linear(in_features=256, out_features=10, bias=True)
#     )
#   )
# )
# (28000, 10)

# %%
vals = np.argmax(answers, axis=1)

# %%
print (answers[:100])
# Out:
# [[ 1.29993844e+00 -4.89649534e+00  2.55245628e+01  1.70980930e+00
#   -2.84616017e+00 -1.40495110e+01 -1.59064695e-01 -4.94721651e+00
#    2.90097451e+00 -8.33792877e+00]
#  [ 2.19995728e+01 -6.79701686e-01  7.10075760e+00 -1.23239744e+00
#   -9.66926193e+00 -3.55155897e+00 -1.21198706e-02  8.13429832e-01
